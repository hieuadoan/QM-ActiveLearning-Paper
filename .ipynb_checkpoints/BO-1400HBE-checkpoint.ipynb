# %%
import numpy as np
import pandas as pd
import pandas as pd
import numpy as np
import rdkit.Chem.Fragments as Fragments
import rdkit.Chem as Chem
import rdkit.Chem.Crippen as Crippen
import rdkit.Chem.Lipinski as Lipinski
import rdkit.Chem.rdMolDescriptors as MolDescriptors
import rdkit.Chem.Descriptors as Descriptors
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.decomposition import PCA
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel
from sklearn.gaussian_process import GaussianProcessRegressor
from scipy.stats import norm
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C ,WhiteKernel as Wht,Matern as matk

df = pd.read_csv('Oxidation-HBE-b3lyp-results-clean.csv')
dataset = df[['canonSMILES','Potential']]

def evaluate_chem_mol(mol):
    mol_sssr = Chem.GetSSSR(mol)
    clogp    = Crippen.MolLogP(mol)
    mr       = Crippen.MolMR(mol)
    mw       = MolDescriptors.CalcExactMolWt(mol)
    tpsa    = MolDescriptors.CalcTPSA(mol)
    Chi0n    = MolDescriptors.CalcChi0n(mol)
    Chi1n    = MolDescriptors.CalcChi1n(mol)
    Chi2n    = MolDescriptors.CalcChi2n(mol)
    Chi3n    = MolDescriptors.CalcChi3n(mol)
    Chi4n    = MolDescriptors.CalcChi4n(mol)
    Chi0v    = MolDescriptors.CalcChi0v(mol)
    Chi1v    = MolDescriptors.CalcChi1v(mol)
    Chi2v    = MolDescriptors.CalcChi2v(mol)
    Chi3v    = MolDescriptors.CalcChi3v(mol)
    Chi4v    = MolDescriptors.CalcChi4v(mol)
    fracsp3  = MolDescriptors.CalcFractionCSP3(mol)
    Hall_Kier_Alpha = MolDescriptors.CalcHallKierAlpha(mol)
    Kappa1      = MolDescriptors.CalcKappa1(mol)
    Kappa2      = MolDescriptors.CalcKappa2(mol)
    Kappa3      = MolDescriptors.CalcKappa3(mol)
    LabuteASA   = MolDescriptors.CalcLabuteASA(mol)
    Number_Aliphatic_Rings = MolDescriptors.CalcNumAliphaticRings(mol)
    Number_Aromatic_Rings = MolDescriptors.CalcNumAromaticRings(mol)
    Number_Amide_Bonds = MolDescriptors.CalcNumAmideBonds(mol)
    Number_Atom_Stereocenters = MolDescriptors.CalcNumAtomStereoCenters(mol)
    Number_BridgeHead_Atoms = MolDescriptors.CalcNumBridgeheadAtoms(mol)
    Number_HBA = MolDescriptors.CalcNumHBA(mol)
    Number_HBD = MolDescriptors.CalcNumHBD(mol)
    Number_Hetero_Atoms = MolDescriptors.CalcNumHeteroatoms(mol)
    Number_Hetero_Cycles = MolDescriptors.CalcNumHeterocycles(mol)
    Number_Rings = MolDescriptors.CalcNumRings(mol)
    Number_Rotatable_Bonds = MolDescriptors.CalcNumRotatableBonds(mol)
    Number_Spiro = MolDescriptors.CalcNumSpiroAtoms(mol)
    Number_Saturated_Rings = MolDescriptors.CalcNumSaturatedRings(mol)
    Number_Heavy_Atoms = Lipinski.HeavyAtomCount(mol)
    Number_NH_OH = Lipinski.NHOHCount(mol)
    Number_N_O = Lipinski.NOCount(mol)
    Number_Valence_Electrons = Descriptors.NumValenceElectrons(mol)
    Max_Partial_Charge = Descriptors.MaxPartialCharge(mol)
    Min_Partial_Charge = Descriptors.MinPartialCharge(mol)

    return mol_sssr, clogp, mr, mw, tpsa, Chi0n, Chi1n, Chi2n, Chi3n, Chi4n, Chi0v, Chi1v, Chi2v, Chi3v, Chi4v, fracsp3, Hall_Kier_Alpha,Kappa1, Kappa2, Kappa3, LabuteASA, Number_Aliphatic_Rings, Number_Aromatic_Rings, Number_Amide_Bonds, Number_Atom_Stereocenters, Number_BridgeHead_Atoms, Number_HBA, Number_HBD, Number_Hetero_Atoms, Number_Hetero_Cycles, Number_Rings, Number_Rotatable_Bonds, Number_Spiro, Number_Saturated_Rings, Number_Heavy_Atoms, Number_NH_OH, Number_N_O, Number_Valence_Electrons, Max_Partial_Charge, Min_Partial_Charge

sssr=[]
clogp=[]
mr=[]
mw=[]
tpsa=[]
chi0n=[]
chi1n=[]
chi2n=[]
chi3n=[]
chi4n=[]
chi0v=[]
chi1v=[]
chi2v=[]
chi3v=[]
chi4v=[]
fracsp3=[]
hall_kier_alpha=[]
kappa1=[]
kappa2=[]
kappa3=[]
labuteasa=[]
number_aliphatic_rings=[]
number_aromatic_rings=[]
number_amide_bonds=[]
number_atom_stereocenters=[]
number_bridgehead_atoms=[]
number_HBA=[]
number_HBD=[]
number_hetero_atoms=[]
number_hetero_cycles=[]
number_rings=[]
number_rotatable_bonds=[]
number_spiro=[]
number_saturated_rings=[]
number_heavy_atoms=[]
number_nh_oh=[]
number_n_o=[]
number_valence_electrons=[]
max_partial_charge=[]
min_partial_charge=[]

fr_C_O = []
fr_C_O_noCOO = []
fr_Al_OH = []
fr_Ar_OH = []
fr_methoxy = []
fr_oxime = []
fr_ester = []
fr_Al_COO = []
fr_Ar_COO = []
fr_COO = []
fr_COO2 = []
fr_ketone = []
fr_ether = []
fr_phenol = []
fr_aldehyde = []
fr_quatN = []
fr_NH2 = []
fr_NH1 = []
fr_NH0 = []
fr_Ar_N = []
fr_Ar_NH = []
fr_aniline = []
fr_Imine = []
fr_nitrile = []
fr_hdrzine = []
fr_hdrzone = []
fr_nitroso = []
fr_N_O = []
fr_nitro = []
fr_azo = []
fr_diazo = []
fr_azide = []
fr_amide = []
fr_priamide = []
fr_amidine = []
fr_guanido = []
fr_Nhpyrrole = []
fr_imide = []
fr_isocyan = []
fr_isothiocyan = []
fr_thiocyan = []
fr_halogen = []
fr_alkyl_halide = []
fr_sulfide = []
fr_SH = []
fr_C_S = []
fr_sulfone = []
fr_sulfonamd = []
fr_prisulfonamd = []
fr_barbitur = []
fr_urea = []
fr_term_acetylene = []
fr_imidazole = []
fr_furan = []
fr_thiophene = []
fr_thiazole = []
fr_oxazole = []
fr_pyridine = []
fr_piperdine = []
fr_piperzine = []
fr_morpholine = []
fr_lactam = []
fr_lactone = []
fr_tetrazole = []
fr_epoxide = []
fr_unbrch_alkane = []
fr_bicyclic = []
fr_benzene = []
fr_phos_acid = []
fr_phos_ester = []
fr_nitro_arom = []
fr_nitro_arom_nonortho = []
fr_dihydropyridine = []
fr_phenol_noOrthoHbond = []
fr_Al_OH_noTert = []
fr_benzodiazepine = []
fr_para_hydroxylation = []
fr_allylic_oxid = []
fr_aryl_methyl = []
fr_Ndealkylation1 = []
fr_Ndealkylation2 = []
fr_alkyl_carbamate = []
fr_ketone_Topliss = []
fr_ArN = []
fr_HOCCN = []

for f in df['canonSMILES']:
    f1=Chem.MolFromSmiles(f)
    mol_sssr, mol_clogp, mol_mr, mol_mw, mol_tpsa, mol_chi0n, mol_chi1n, mol_chi2n, mol_chi3n, mol_chi4n, mol_chi0v, mol_chi1v, mol_chi2v, mol_chi3v, mol_chi4v, mol_fracsp3, mol_hall_kier_alpha, mol_kappa1, mol_kappa2, mol_kappa3, mol_labuteasa, mol_number_aliphatic_rings, mol_number_aromatic_rings, mol_number_amide_bonds, mol_number_atom_stereocenters, mol_number_bridgehead_atoms, mol_number_HBA, mol_number_HBD, mol_number_hetero_atoms, mol_number_hetero_cycles, mol_number_rings, mol_number_rotatable_bonds, mol_number_spiro, mol_number_saturated_rings, mol_number_heavy_atoms, mol_number_nh_oh, mol_number_n_o, mol_number_valence_electrons, mol_max_partial_charge, mol_min_partial_charge= evaluate_chem_mol(f1)

    sssr.append(mol_sssr)
    clogp.append(mol_clogp)
    mr.append(mol_mr)
    mw.append(mol_mw)
    tpsa.append(mol_tpsa)
    chi0n.append(mol_chi0n)
    chi1n.append(mol_chi1n)
    chi2n.append(mol_chi2n)
    chi3n.append(mol_chi3n)
    chi4n.append(mol_chi4n)
    chi0v.append(mol_chi0v)
    chi1v.append(mol_chi1v)
    chi2v.append(mol_chi2v)
    chi3v.append(mol_chi3v)
    chi4v.append(mol_chi4v)
    fracsp3.append(mol_fracsp3)
    hall_kier_alpha.append(mol_hall_kier_alpha)
    kappa1.append(mol_kappa1)
    kappa2.append(mol_kappa2)
    kappa3.append(mol_kappa3)
    labuteasa.append(mol_labuteasa)
    number_aliphatic_rings.append(mol_number_aliphatic_rings)
    number_aromatic_rings.append(mol_number_aromatic_rings)
    number_amide_bonds.append(mol_number_amide_bonds)
    number_atom_stereocenters.append(mol_number_atom_stereocenters)
    number_bridgehead_atoms.append(mol_number_bridgehead_atoms)
    number_HBA.append(mol_number_HBA)
    number_HBD.append(mol_number_HBD)
    number_hetero_atoms.append(mol_number_hetero_atoms)
    number_hetero_cycles.append(mol_number_hetero_cycles)
    number_rings.append(mol_number_rings)
    number_rotatable_bonds.append(mol_number_rotatable_bonds)
    number_spiro.append(mol_number_spiro)
    number_saturated_rings.append(mol_number_saturated_rings)
    number_heavy_atoms.append(mol_number_heavy_atoms)
    number_nh_oh.append(mol_number_nh_oh)
    number_n_o.append(mol_number_n_o)
    number_valence_electrons.append(mol_number_valence_electrons)
    max_partial_charge.append(mol_max_partial_charge)
    min_partial_charge.append(mol_min_partial_charge)

    fr_C_O.append(Fragments.fr_C_O(f1))
    fr_C_O_noCOO.append(Fragments.fr_C_O_noCOO(f1))
    fr_Al_OH.append(Fragments.fr_Al_OH(f1))
    fr_Ar_OH.append(Fragments.fr_Ar_OH(f1))
    fr_methoxy.append(Fragments.fr_methoxy(f1))
    fr_oxime.append(Fragments.fr_oxime(f1))
    fr_ester.append(Fragments.fr_ester(f1))
    fr_Al_COO.append(Fragments.fr_Al_COO(f1))
    fr_Ar_COO.append(Fragments.fr_Ar_COO(f1))
    fr_COO.append(Fragments.fr_COO(f1))
    fr_COO2.append(Fragments.fr_COO2(f1))
    fr_ketone.append(Fragments.fr_ketone(f1))
    fr_ether.append(Fragments.fr_ether(f1))
    fr_phenol.append(Fragments.fr_phenol(f1))
    fr_aldehyde.append(Fragments.fr_aldehyde(f1))
    fr_quatN.append(Fragments.fr_quatN(f1))
    fr_NH2.append(Fragments.fr_NH2(f1))
    fr_NH1.append(Fragments.fr_NH1(f1))
    fr_NH0.append(Fragments.fr_NH0(f1))
    fr_Ar_N.append(Fragments.fr_Ar_N(f1))
    fr_Ar_NH.append(Fragments.fr_Ar_NH(f1))
    fr_aniline.append(Fragments.fr_aniline(f1))
    fr_Imine.append(Fragments.fr_Imine(f1))
    fr_nitrile.append(Fragments.fr_nitrile(f1))
    fr_hdrzine.append(Fragments.fr_hdrzine(f1))
    fr_hdrzone.append(Fragments.fr_hdrzone(f1))
    fr_nitroso.append(Fragments.fr_nitroso(f1))
    fr_N_O.append(Fragments.fr_N_O(f1))
    fr_nitro.append(Fragments.fr_nitro(f1))
    fr_azo.append(Fragments.fr_azo(f1))
    fr_diazo.append(Fragments.fr_diazo(f1))
    fr_azide.append(Fragments.fr_azide(f1))
    fr_amide.append(Fragments.fr_amide(f1))
    fr_priamide.append(Fragments.fr_priamide(f1))
    fr_amidine.append(Fragments.fr_amidine(f1))
    fr_guanido.append(Fragments.fr_guanido(f1))
    fr_Nhpyrrole.append(Fragments.fr_Nhpyrrole(f1))
    fr_imide.append(Fragments.fr_imide(f1))
    fr_isocyan.append(Fragments.fr_isocyan(f1))
    fr_isothiocyan.append(Fragments.fr_isothiocyan(f1))
    fr_thiocyan.append(Fragments.fr_thiocyan(f1))
    fr_halogen.append(Fragments.fr_halogen(f1))
    fr_alkyl_halide.append(Fragments.fr_alkyl_halide(f1))
    fr_sulfide.append(Fragments.fr_sulfide(f1))
    fr_SH.append(Fragments.fr_SH(f1))
    fr_C_S.append(Fragments.fr_C_S(f1))
    fr_sulfone.append(Fragments.fr_sulfone(f1))
    fr_sulfonamd.append(Fragments.fr_sulfonamd(f1))
    fr_prisulfonamd.append(Fragments.fr_prisulfonamd(f1))
    fr_barbitur.append(Fragments.fr_barbitur(f1))
    fr_urea.append(Fragments.fr_urea(f1))
    fr_term_acetylene.append(Fragments.fr_term_acetylene(f1))
    fr_imidazole.append(Fragments.fr_imidazole(f1))
    fr_furan.append(Fragments.fr_furan(f1))
    fr_thiophene.append(Fragments.fr_thiophene(f1))
    fr_thiazole.append(Fragments.fr_thiazole(f1))
    fr_oxazole.append(Fragments.fr_oxazole(f1))
    fr_pyridine.append(Fragments.fr_pyridine(f1))
    fr_piperdine.append(Fragments.fr_piperdine(f1))
    fr_piperzine.append(Fragments.fr_piperzine(f1))
    fr_morpholine.append(Fragments.fr_morpholine(f1))
    fr_lactam.append(Fragments.fr_lactam(f1))
    fr_lactone.append(Fragments.fr_lactone(f1))
    fr_tetrazole.append(Fragments.fr_tetrazole(f1))
    fr_epoxide.append(Fragments.fr_epoxide(f1))
    fr_unbrch_alkane.append(Fragments.fr_unbrch_alkane(f1))
    fr_bicyclic.append(Fragments.fr_bicyclic(f1))
    fr_benzene.append(Fragments.fr_benzene(f1))
    fr_phos_acid.append(Fragments.fr_phos_acid(f1))
    fr_phos_ester.append(Fragments.fr_phos_ester(f1))
    fr_nitro_arom.append(Fragments.fr_nitro_arom(f1))
    fr_nitro_arom_nonortho.append(Fragments.fr_nitro_arom_nonortho(f1))
    fr_dihydropyridine.append(Fragments.fr_dihydropyridine(f1))
    fr_phenol_noOrthoHbond.append(Fragments.fr_phenol_noOrthoHbond(f1))
    fr_Al_OH_noTert.append(Fragments.fr_Al_OH_noTert(f1))
    fr_benzodiazepine.append(Fragments.fr_benzodiazepine(f1))
    fr_para_hydroxylation.append(Fragments.fr_para_hydroxylation(f1))
    fr_allylic_oxid.append(Fragments.fr_allylic_oxid(f1))
    fr_aryl_methyl.append(Fragments.fr_aryl_methyl(f1))
    fr_Ndealkylation1.append(Fragments.fr_Ndealkylation1(f1))
    fr_Ndealkylation2.append(Fragments.fr_Ndealkylation2(f1))
    fr_alkyl_carbamate.append(Fragments.fr_alkyl_carbamate(f1))
    fr_ketone_Topliss.append(Fragments.fr_ketone_Topliss(f1))
    fr_ArN.append(Fragments.fr_ArN(f1))
    fr_HOCCN.append(Fragments.fr_HOCCN(f1))


df_Solvent_Features=pd.DataFrame(
   {'sssr':sssr,
    'clogp':clogp,
    'mr':mr,
    'mw':mw,
    'tpsa': tpsa,
    'chi0n':chi0n,
    'chi1n':chi1n,
    'chi2n':chi2n,
    'chi3n':chi3n,
    'chi4n':chi4n,
    'chi0v':chi0v,
    'chi1v':chi1v,
    'chi2v':chi2v,
    'chi3v':chi3v,
    'chi4v':chi4v,
    'fracsp3':fracsp3,
    'hall_kier_alpha':hall_kier_alpha,
    'kappa1':kappa1,
    'kappa2':kappa2,
    'kappa3':kappa3,
    'labuteasa':labuteasa,
    'number_aliphatic_rings':number_aliphatic_rings,
    'number_aromatic_rings':number_aromatic_rings,
    'number_amide_bonds':number_amide_bonds,
    'number_atom_stereocenters':number_atom_stereocenters,
    'number_bridgehead_atoms':number_bridgehead_atoms,
    'number_HBA':number_HBA,
    'number_HBD':number_HBD,
    'number_hetero_atoms':number_hetero_atoms,
    'number_hetero_cycles':number_hetero_cycles,
    'number_rings':number_rings,
    'number_rotatable_bonds':number_rotatable_bonds,
    'number_spiro':number_spiro,
    'number_saturated_rings':number_saturated_rings,
    'number_heavy_atoms':number_heavy_atoms,
    'number_nh_oh':number_nh_oh,
    'number_n_o':number_n_o,
    'number_valence_electrons':number_valence_electrons,
    'max_partial_charge':max_partial_charge,
    'min_partial_charge':min_partial_charge
   })

df_Solvent_Features_Frags=pd.DataFrame(
    {'fr_C_O':fr_C_O,
    'fr_C_O_noCOO':fr_C_O_noCOO,
    'fr_Al_OH':fr_Al_OH,
    'fr_Ar_OH':fr_Ar_OH,
    'fr_methoxy':fr_methoxy,
    'fr_oxime':fr_oxime,
    'fr_ester':fr_ester,
    'fr_Al_COO':fr_Al_COO,
    'fr_Ar_COO':fr_Ar_COO,
    'fr_COO':fr_COO,
    'fr_COO2':fr_COO2,
    'fr_ketone':fr_ketone,
    'fr_ether':fr_ether,
    'fr_phenol':fr_phenol,
    'fr_aldehyde':fr_aldehyde,
    'fr_quatN':fr_quatN,
    'fr_NH2':fr_NH2,
    'fr_NH1':fr_NH1,
    'fr_NH0':fr_NH0,
    'fr_Ar_N':fr_Ar_N,
    'fr_Ar_NH':fr_Ar_NH,
    'fr_aniline':fr_aniline,
    'fr_Imine':fr_Imine,
    'fr_nitrile':fr_nitrile,
    'fr_hdrzine':fr_hdrzine,
    'fr_hdrzone':fr_hdrzone,
    'fr_nitroso':fr_nitroso,
    'fr_N_O':fr_N_O,
    'fr_nitro':fr_nitro,
    'fr_azo':fr_azo,
    'fr_diazo':fr_diazo,
    'fr_azide':fr_azide,
    'fr_amide':fr_amide,
    'fr_priamide':fr_priamide,
    'fr_amidine':fr_amidine,
    'fr_guanido':fr_guanido,
    'fr_Nhpyrrole':fr_Nhpyrrole,
    'fr_imide':fr_imide,
    'fr_isocyan':fr_isocyan,
    'fr_isothiocyan':fr_isothiocyan,
    'fr_thiocyan':fr_thiocyan,
    'fr_halogen':fr_halogen,
    'fr_alkyl_halide':fr_alkyl_halide,
    'fr_sulfide':fr_sulfide,
    'fr_SH':fr_SH,
    'fr_C_S':fr_C_S,
    'fr_sulfone':fr_sulfone,
    'fr_sulfonamd':fr_sulfonamd,
    'fr_prisulfonamd':fr_prisulfonamd,
    'fr_barbitur':fr_barbitur,
    'fr_urea':fr_urea,
    'fr_term_acetylene':fr_term_acetylene,
    'fr_imidazole':fr_imidazole,
    'fr_furan':fr_furan,
    'fr_thiophene':fr_thiophene,
    'fr_thiazole':fr_thiazole,
    'fr_oxazole':fr_oxazole,
    'fr_pyridine':fr_pyridine,
    'fr_piperdine':fr_piperdine,
    'fr_piperzine':fr_piperzine,
    'fr_morpholine':fr_morpholine,
    'fr_lactam':fr_lactam,
    'fr_lactone':fr_lactone,
    'fr_tetrazole':fr_tetrazole,
    'fr_epoxide':fr_epoxide,
    'fr_unbrch_alkane':fr_unbrch_alkane,
    'fr_bicyclic':fr_bicyclic,
    'fr_benzene':fr_benzene,
    'fr_phos_acid':fr_phos_acid,
    'fr_phos_ester':fr_phos_ester,
    'fr_nitro_arom':fr_nitro_arom,
    'fr_nitro_arom_nonortho':fr_nitro_arom_nonortho,
    'fr_dihydropyridine':fr_dihydropyridine,
    'fr_phenol_noOrthoHbond':fr_phenol_noOrthoHbond,
    'fr_Al_OH_noTert':fr_Al_OH_noTert,
    'fr_benzodiazepine':fr_benzodiazepine,
    'fr_para_hydroxylation':fr_para_hydroxylation,
    'fr_allylic_oxid':fr_allylic_oxid,
    'fr_aryl_methyl':fr_aryl_methyl,
    'fr_Ndealkylation1':fr_Ndealkylation1,
    'fr_Ndealkylation2':fr_Ndealkylation2,
    'fr_alkyl_carbamate':fr_alkyl_carbamate,
    'fr_ketone_Topliss':fr_ketone_Topliss,
    'fr_ArN':fr_ArN,
    'fr_HOCCN':fr_HOCCN})

df_Solvent_Features_All = pd.concat([df_Solvent_Features,df_Solvent_Features_Frags], axis=1)

X = df_Solvent_Features_All
Y=df.Potential.values

target_val = 1.5500
Ydata = -1*abs(dataset.Potential.values-target_val)
Xinfo = dataset.canonSMILES.values
ndata = len(Ydata)

st = StandardScaler()
Xdata = st.fit_transform(X)

nPC = 15
pca = PCA(n_components=nPC)
Xdata = pca.fit_transform(Xdata)

natom_layer = Xdata.shape[1]

def gpregression(Xtrain,Ytrain,Nfeature):
    cmean=[1.0]*nPC
    cbound=[[1e-3, 1e3]]*nPC
#   kernel = C(1.0, (1e-3,1e3)) * RBF(cmean, cbound) + Wht(1.0, (1e-3, 1e3))
    kernel = C(1.0, (1e-3,1e3)) * matk(cmean,cbound,1.5) + Wht(1.0, (1e-3, 1e3))
    gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=40, normalize_y=False)
    gp.fit(Xtrain, Ytrain)
    return gp

#predict result using GP regression model
def gprediction(gpnetwork,xtest):
    y_pred, sigma = gpnetwork.predict(xtest, return_std=True)
    return y_pred, sigma

#compute expected improvement
def expectedimprovement(xdata,gpnetwork,ybest,itag,epsilon):
    ye_pred, esigma = gprediction(gpnetwork, xdata)
    expI = np.empty(ye_pred.size, dtype=float)
    for ii in range(0,ye_pred.size):
        if esigma[ii] > 0:
            zzval=itag*(ye_pred[ii]-ybest)/float(esigma[ii])
            expI[ii]=itag*(ye_pred[ii]-ybest-epsilon)*norm.cdf(zzval)+esigma[ii]*norm.pdf(zzval)
        else:
            expI[ii]=0.0
    return expI

#Bayesian optimization run

def numberofopt(Xdata,Ydata,Xinfo,ndata,natom_layer):
    itag = 1
    epsilon = 0.01  # 0.1
    ntrain = 5 # int(train_test_split * ndata)
    nremain = ndata - ntrain
    dataset = np.random.permutation(ndata)
    a1data = np.empty(ntrain, dtype=int)
    a2data = np.empty(nremain, dtype=int)
    a1data[:] = dataset[0:ntrain]
    a2data[:] = dataset[ntrain:ndata]
    # info for the initial training set
    Xtrain = np.ndarray(shape=(ntrain, natom_layer), dtype=float)
    Xtraininfo = np.chararray(ntrain, itemsize=100)
    Ytrain = np.empty(ntrain, dtype=float)
    Xtrain[0:ntrain, :] = Xdata[a1data, :]
    Xtraininfo[0:ntrain] = Xinfo[a1data]
    Ytrain[0:ntrain] = Ydata[a1data]
    YtrainIniList = Ytrain.tolist()
    XtraininfoIni = Xtraininfo
    XtraininfoIni=np.array([x.decode() for x in XtraininfoIni])
    XtraininfoIniList = XtraininfoIni.tolist()
    yoptLoc = np.argmax(Ytrain)
    yopttval = Ytrain[yoptLoc]
    xoptval = Xtraininfo[yoptLoc]
    yoptstep=0
    yopinit = yopttval
    xoptint = xoptval
    # info for the remaining data set
    Xremain = np.ndarray(shape=(nremain, natom_layer), dtype=float)
    Xremaininfo = np.chararray(nremain, itemsize=100)
    Yremain = np.empty(nremain, dtype=float)
    Xremain[0:nremain, :] = Xdata[a2data, :]
    Xremaininfo[0:nremain] = Xinfo[a2data]
    Yremain[0:nremain] = Ydata[a2data]
    targetRM = []
    maeList = []
    rmseList= []
    for ii in range(0, Niteration):
        if ii > int(0.5*Niteration):
            epsilon=0.01
        gpnetwork = gpregression(Xtrain, Ytrain, natom_layer)
        yt_pred, tsigma = gprediction(gpnetwork, Xtrain)

        ybestloc = np.argmax(yt_pred)
        ybest = yt_pred[ybestloc]
        ytrue = Ytrain[ybestloc]

        sumAbsError = 0
        sumSquError = 0
        #Evaluate the current metrics
        for i in range(len(Xtrain)):
            absError = np.abs(yt_pred[i]-Ytrain[i])
            sumAbsError += absError
            sumSquError += absError**2
        mae = sumAbsError/len(Xtraininfo)
        mse = sumSquError/len(Xtraininfo)
        rmse = np.sqrt(mse)
        maeList.append(mae)
        rmseList.append(rmse)

        if yopttval < ytrue:
            yopttval = ytrue
            xoptval = Xtraininfo[ybestloc]

        print("Current best molecule is ", xoptval.decode()," with true y = ", yopttval)
        expI = expectedimprovement(Xremain, gpnetwork, ybest, itag, epsilon)
        expImax = np.max(expI)
        expimaxloc = np.argmax(expI)
        print("Next molecule to evaluate is ", Xremaininfo[expimaxloc].decode(),
              "with predicted y = ",ybest," and true y = ", Yremain[expimaxloc])
        xnew = np.append(Xtrain, Xremain[expimaxloc]).reshape(-1, natom_layer)
        xnewinfo = np.append(Xtraininfo, Xremaininfo[expimaxloc])
        ynew = np.append(Ytrain, Yremain[expimaxloc])
        xrnew = np.delete(Xremain, expimaxloc, 0)
        xrnewinfo = np.delete(Xremaininfo, expimaxloc)
        yrnew = np.delete(Yremain, expimaxloc)
        if ii==0:
            Xexplored=Xremaininfo[expimaxloc]
            Yexplored=Yremain[expimaxloc]
        else:
            Xexploredtemp=np.append(Xexplored, Xremaininfo[expimaxloc])
            Yexploredtemp=np.append(Yexplored, Yremain[expimaxloc])
            del Xexplored,Yexplored
            Xexplored=Xexploredtemp
            Yexplored=Yexploredtemp
        del Xtrain, Ytrain, Xremaininfo, gpnetwork
        Xtrain = xnew
        Xtraininfo = xnewinfo
        Ytrain = ynew
        Xremain = xrnew
        Xremaininfo = xrnewinfo
        Yremain = yrnew
        del xnew, xnewinfo, ynew, xrnew, xrnewinfo, yrnew

    if not yopinit==yopttval:
        yoptstep = np.argmax(Yexplored) + 1
    else:
        yoptstep=0
    dataorder = np.argsort(Yexplored)
    Yexploredtemp=Yexplored[dataorder]
    Xexploredtemp = Xexplored[dataorder]
    YexploredList = Yexplored.tolist()
    Xexplored=np.array([x.decode() for x in Xexplored])
    XexploredList = Xexplored.tolist()
    result = YtrainIniList+YexploredList+XtraininfoIniList+XexploredList
    Xbest=Xexploredtemp[Niteration-3:Niteration]
    Ybest=Yexploredtemp[Niteration - 3:Niteration]
    return xoptint,yopinit,xoptval,yopttval,maeList,rmseList,result


#------- Program Starts from here -------------
fileName = 'BayesOptRunProgress'
pfile = open(fileName+'.txt','a+')
pfile.write("Original Training X and Y : \n")
pfile.write(str(np.shape(Xdata)))
pfile.write(str(np.shape(Ydata)))
pfile.write("\n")
pfile.close()
ntrain = 5
Nruns = 1   # Number of repeated Bayesian Optimaization runs
Niteration = 100           # number of iterations in a given Bayesian Optimization

Xinitguess = np.chararray(Nruns, itemsize=100)
Yinitguess = np.empty(Nruns, dtype=float)
Xoptimal = np.chararray(Nruns, itemsize=100)
Yoptimal = np.empty(Nruns, dtype=float)
metricsMAE=[]
metricsRMSE=[]
res = []
for ii in range(0,Nruns):
    Xinitguess[ii], Yinitguess[ii], Xoptimal[ii], Yoptimal[ii], meanAbErrList, rootMSEList, resultRow =numberofopt(Xdata, Ydata, Xinfo, ndata, natom_layer)
    pfile = open(fileName+'.txt','a+')
    pfile.write("Run #"+str(ii+1)+"\n")
    pfile.write("Initial Best Strucuture:   "+ Xinitguess[ii].decode()+ "  has value:  "+ str(Yinitguess[ii])+"  Final Optimal Structure:   "+ Xoptimal[ii].decode()+ "  has value: "+ str(Yoptimal[ii])+"\n")
    pfile.write('---------------------------\n')
    pfile.close()
    res.append(resultRow)
    metricsMAE.append(meanAbErrList)
    metricsRMSE.append(rootMSEList)
    print('List of HBEs with 1.40 V < Eox < 1.70 V: ')
    for i,a in enumerate(resultRow):
        if i<ntrain+Niteration and abs(a)<=0.15:
            print(resultRow[i+ntrain+Niteration])
dfMAE = pd.DataFrame.from_records(metricsMAE)
dfRMSE = pd.DataFrame.from_records(metricsRMSE)
df = pd.DataFrame.from_records(res)

dfMAE.to_csv('MAE.csv',index=False)
dfRMSE.to_csv('RMSE.csv',index=False)
df.to_csv('BayesOptResult.csv',index=False)
# Out:
# /Users/hadoan/anaconda3/envs/mlmat/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/hadoan/anaconda3/envs/mlmat/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# Current best molecule is  O=[N+]([O-])c1ccc(CC(Oc2ccccc2)c2ccccc2)cc1  with true y =  -0.27276763999999987
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1 with predicted y =  -0.2771826678184004  and true y =  -0.05987660000000017
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COC(OC)C(C#N)(c1ccccc1)c1ccc([N+](=O)[O-])cc1 with predicted y =  -0.059499624288057884  and true y =  -1.03023962
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COCOC(OC)C(C)c1ccc(C(=O)OC)cc1 with predicted y =  -0.06172076630431267  and true y =  -0.9040124300000001
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COCOC(C#N)C(C#N)(C#N)c1ccc(N(C)C)cc1 with predicted y =  -0.06319007129271847  and true y =  -0.28827535000000015
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  N#CC(Oc1ccccc1)C(C#N)(C#N)c1ccc([N+](=O)[O-])cc1 with predicted y =  -0.06255100925425339  and true y =  -0.81680438
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  CC(c1ccc([N+](=O)[O-])cc1)C(Br)Oc1ccccc1 with predicted y =  -0.06400918385798882  and true y =  -0.5683498699999998
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  N#CC(C#N)(c1ccccc1)C(Br)Oc1ccccc1 with predicted y =  -0.06346497568177034  and true y =  -0.7607789900000002
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COCOC(c1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(-c2ccccc2)cc1 with predicted y =  -0.06465564708632754  and true y =  -0.13954748000000006
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COCOC(C#N)C(C)(C)c1ccc(OC)cc1 with predicted y =  -0.06575865491773936  and true y =  -0.18577727
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  c1ccc(OC(c2ccccc2)C(c2ccccc2)(c2ccccc2)c2ccc(-c3ccccc3)cc2)cc1 with predicted y =  -0.06298634750296217  and true y =  -0.16936964
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COc1ccc(C(C#N)(C#N)C(C#N)OC)cc1 with predicted y =  -0.0631656467151962  and true y =  -0.6929444599999999
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1  with true y =  -0.05987660000000017
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1 with predicted y =  -0.06033109586041263  and true y =  -0.03361696000000003
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(Br)C(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.03256044378966738  and true y =  -0.08248810999999989
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  CCc1ccc(C(c2ccccc2)(c2ccccc2)C(Oc2ccccc2)c2ccccc2)cc1 with predicted y =  -0.07783804499229063  and true y =  -0.23108192000000005
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(c1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.11092741198413236  and true y =  -0.11938486999999998
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  c1ccc(OCC(c2ccccc2)(c2ccccc2)c2ccc(-c3ccccc3)cc2)cc1 with predicted y =  -0.0883555865908594  and true y =  -0.17973664999999994
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(Br)Cc1ccc(OC)cc1 with predicted y =  -0.040050913409793054  and true y =  -0.11998348999999986
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(OC)C(c1ccccc1)(c1ccccc1)c1ccc(N(C)C)cc1 with predicted y =  -0.038447799625658696  and true y =  -0.7688311600000001
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(Br)C(C)(C)c1ccc(OC)cc1 with predicted y =  -0.047521596579532144  and true y =  -0.1601454499999999
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(Br)Cc1ccc(C(=O)OC)cc1 with predicted y =  -0.03757319559466055  and true y =  -0.9222975499999999
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  CCc1ccc(CCOCOC)cc1 with predicted y =  -0.03446952656421054  and true y =  -0.46443488
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCCc1ccc(OC)cc1 with predicted y =  -0.034477629026346435  and true y =  -0.040856809999999966
# Current best molecule is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.03361696000000003
# Next molecule to evaluate is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.034758002668265675  and true y =  -0.029292560000000023
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  CCc1ccc(C(C#N)(C#N)C(Br)OCOC)cc1 with predicted y =  -0.03064455824841339  and true y =  -0.9881457499999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCCc1ccccc1 with predicted y =  -0.025526174454581607  and true y =  -0.6388509799999997
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOC(C)Cc1ccc(OC)cc1 with predicted y =  -0.02394439673808435  and true y =  -0.0644478799999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  CCc1ccc(C(C)(C)COC)cc1 with predicted y =  -0.02991278217871063  and true y =  -0.4407621799999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOC(Br)C(C#N)(C#N)c1ccc(C(=O)OC)cc1 with predicted y =  -0.024126834576698286  and true y =  -1.3809221
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOCCc1ccc(OC)cc1 with predicted y =  -0.028213944707633942  and true y =  -0.06643420999999994
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOCCc1ccccc1 with predicted y =  -0.026900712233556945  and true y =  -0.7060596799999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COc1ccc(CC(OC)OC)cc1 with predicted y =  -0.026383376008677573  and true y =  -0.0889913
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COc1ccc(C(C)C(OC)Oc2ccccc2)cc1 with predicted y =  -0.028335832590755672  and true y =  -0.03916978999999987
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOC(OC)C(C#N)(C#N)c1ccc([N+](=O)[O-])cc1 with predicted y =  -0.031965939545406385  and true y =  -1.7495631799999998
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  CN(C)c1ccc(C(C#N)(C#N)C(C#N)Oc2ccccc2)cc1 with predicted y =  -0.030928084549138646  and true y =  -0.24076669000000006
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOCCc1ccc(C(=O)OC)cc1 with predicted y =  -0.03374112741389368  and true y =  -0.9427594700000002
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOCC(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.030376356651929726  and true y =  -0.05846167999999996
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  CCc1ccc(C(C)(C#N)C(C#N)OC)cc1 with predicted y =  -0.03018667208940151  and true y =  -0.8652109699999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  O=[N+]([O-])c1ccc(C(c2ccccc2)(c2ccccc2)C(Oc2ccccc2)c2ccccc2)cc1 with predicted y =  -0.0313705315228745  and true y =  -0.32158237999999995
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COC(=O)c1ccc(C(C#N)(C#N)COc2ccccc2)cc1 with predicted y =  -0.030284062933290556  and true y =  -0.5126237899999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COc1ccc(C(COc2ccccc2)(c2ccccc2)c2ccccc2)cc1 with predicted y =  -0.03052238803723384  and true y =  -0.09005248999999993
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COC(=O)c1ccc(C(C)(C#N)C(C)OC)cc1 with predicted y =  -0.0318066325252051  and true y =  -1.0579393999999998
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOC(Cc1ccc(OC)cc1)OC with predicted y =  -0.035816367382608405  and true y =  -0.07195784000000005
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  CN(C)c1ccc(C(C#N)(c2ccccc2)C(C#N)Oc2ccccc2)cc1 with predicted y =  -0.032984016889237466  and true y =  -0.45063742000000007
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COc1ccc(C(C)(C)C(OC)OC)cc1 with predicted y =  -0.03360889647654375  and true y =  -0.025102219999999953
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COc1ccc(C(C)(C)C(Br)OC)cc1 with predicted y =  -0.029630753490010875  and true y =  -0.15168314000000005
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  N#Cc1ccc(C(C#N)(C#N)C(C#N)Oc2ccccc2)cc1 with predicted y =  -0.03201766837094766  and true y =  -0.7999341799999999
# Current best molecule is  COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1  with true y =  -0.029292560000000023
# Next molecule to evaluate is  COCOC(OC)C(C#N)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.030265413656225704  and true y =  -0.30005927
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COC(C)C(C)c1ccc([N+](=O)[O-])cc1 with predicted y =  -0.03482609376692025  and true y =  -1.1722214
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  CN(C)c1ccc(C(COc2ccccc2)c2ccccc2)cc1 with predicted y =  -0.028623279949584912  and true y =  -0.75196096
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COC(C)C(C)(c1ccccc1)c1ccc([N+](=O)[O-])cc1 with predicted y =  -0.028775436517108233  and true y =  -0.75356834
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COC(c1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(-c2ccccc2)cc1 with predicted y =  -0.0291215417018984  and true y =  -0.13628227999999987
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COCC(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.029270440262138875  and true y =  -0.05152312999999986
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COc1ccc(C(C)(C)C(OC)Oc2ccccc2)cc1 with predicted y =  -0.028079905005346184  and true y =  -0.032231239999999994
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COc1ccc(C(C)(c2ccccc2)C(C)OC)cc1 with predicted y =  -0.033061889158314095  and true y =  -0.025481169999999942
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(Br)OC)cc1 with predicted y =  -0.02623570076808024  and true y =  -0.12324869000000005
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(Oc2ccccc2)c2ccccc2)cc1 with predicted y =  -0.026727675704323772  and true y =  -0.04270708999999995
# Current best molecule is  COc1ccc(C(C)(C)C(OC)OC)cc1  with true y =  -0.025102219999999953
# Next molecule to evaluate is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1 with predicted y =  -0.02675204723814595  and true y =  -0.006080440000000076
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COCOC(C)C(C)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.009807689454882862  and true y =  -0.02254248999999997
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(Br)Oc2ccccc2)cc1 with predicted y =  -0.013946296291330817  and true y =  -0.12346637000000005
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COCOC(OC)C(C)(C)c1ccc(OC)cc1 with predicted y =  -0.009398389185815148  and true y =  -0.028557889999999864
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COCOC(OC)C(C)c1ccc(OC)cc1 with predicted y =  -0.009385716627896556  and true y =  -0.004640299999999931
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COc1ccc(C(C)(c2ccccc2)C(OC)OC)cc1 with predicted y =  -0.009413966868493162  and true y =  -0.007905499999999899
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COCOC(OC)C(C)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.009065275304473985  and true y =  -0.05933239999999973
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(OC)c2ccccc2)cc1 with predicted y =  -0.009259830676356273  and true y =  -0.034299199999999974
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COc1ccc(C(C)C(OC)OC)cc1 with predicted y =  -0.011205755013495633  and true y =  -0.011361170000000032
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COc1ccc(C(C)C(C)OC)cc1 with predicted y =  -0.003607672423948216  and true y =  -0.005755909999999975
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  COCOCC(C)c1ccc(OC)cc1 with predicted y =  -0.010352948917621063  and true y =  -0.046380439999999856
# Current best molecule is  COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1  with true y =  -0.006080440000000076
# Next molecule to evaluate is  CCc1ccc(C(C#N)(C#N)C(C#N)Oc2ccccc2)cc1 with predicted y =  -0.010898477493924474  and true y =  -0.7656223699999998
# Current best molecule is  COCOC(OC)C(C)c1ccc(OC)cc1  with true y =  -0.004640299999999931
# Next molecule to evaluate is  COCOCC(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.012121813585686425  and true y =  -0.046652539999999965
# Current best molecule is  COCOC(OC)C(C)c1ccc(OC)cc1  with true y =  -0.004640299999999931
# Next molecule to evaluate is  COCOC(C)C(C)c1ccc(OC)cc1 with predicted y =  -0.010647490431047402  and true y =  -0.03870722000000004
# Current best molecule is  COCOC(OC)C(C)c1ccc(OC)cc1  with true y =  -0.004640299999999931
# Next molecule to evaluate is  COc1ccc(C(C)(c2ccccc2)C(OC)Oc2ccccc2)cc1 with predicted y =  -0.011617169999571075  and true y =  -0.019034389999999846
# Current best molecule is  COCOC(OC)C(C)c1ccc(OC)cc1  with true y =  -0.004640299999999931
# Next molecule to evaluate is  COc1ccc(C(C)C(OC)c2ccccc2)cc1 with predicted y =  -0.011627393265461805  and true y =  -0.002599550000000006
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(C)OC)cc1 with predicted y =  -0.008270871539824753  and true y =  -0.03421757000000003
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(OC)Oc2ccccc2)cc1 with predicted y =  -0.011427977156714064  and true y =  -0.08322278000000005
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(OC)OC)cc1 with predicted y =  -0.012329851560217264  and true y =  -0.02629945999999994
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(C)(C)C(C)OC)cc1 with predicted y =  -0.011501565666407032  and true y =  -0.004640299999999931
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(C)(C)C(OC)c2ccccc2)cc1 with predicted y =  -0.004431554806554772  and true y =  -0.04507435999999987
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COC(=O)c1ccc(CCOc2ccccc2)cc1 with predicted y =  -0.002365371453756815  and true y =  -0.26645491999999993
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOC(c1ccccc1)C(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.0055979689283418566  and true y =  -0.04863887
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(CC(C)OC)cc1 with predicted y =  -0.0007873893234826568  and true y =  -0.032530549999999936
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCC(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.0008490787016848245  and true y =  -0.047468839999999846
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCC(C)c1ccc(OC)cc1 with predicted y =  -0.0008476444540912453  and true y =  -0.03829906999999988
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOC(C)C(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.0008495401498223032  and true y =  -0.06349552999999997
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(Oc2ccccc2)c2ccccc2)cc1 with predicted y =  -0.007188064605458067  and true y =  -0.06950893999999996
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  CC(Oc1ccccc1)C(C)(C#N)c1ccc([N+](=O)[O-])cc1 with predicted y =  -0.007015638855166095  and true y =  -0.35570371999999995
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)(c2ccccc2)C(C)OC)cc1 with predicted y =  -0.006803998158924074  and true y =  -0.10975252999999996
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOCC(C)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.007404670501237831  and true y =  -0.05593114999999993
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(CC(OC)Oc2ccccc2)cc1 with predicted y =  -0.0075705998047794765  and true y =  -0.05633929999999987
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOCC(C)(C)c1ccc(OC)cc1 with predicted y =  -0.007705579280155916  and true y =  -0.03454409000000003
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOC(C)C(C)(C)c1ccc(OC)cc1 with predicted y =  -0.007660670753608656  and true y =  -0.008474920000000052
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCC(C)(C)c1ccc(OC)cc1 with predicted y =  -0.006256641697284238  and true y =  -0.022190750000000037
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOC(c1ccccc1)C(C)c1ccc(OC)cc1 with predicted y =  -0.005039595961854104  and true y =  -0.05323736000000001
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCC(C)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.005065790504374945  and true y =  -0.011551639999999974
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(CC(OC)c2ccccc2)cc1 with predicted y =  -0.006233096002645766  and true y =  -0.0535094599999999
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COCOC(c1ccccc1)C(C)(c1ccccc1)c1ccc(OC)cc1 with predicted y =  -0.006029247342951294  and true y =  -0.03685694000000006
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(C)C(C)Oc2ccccc2)cc1 with predicted y =  -0.005586313431194867  and true y =  -0.004096100000000158
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(C)(C)C(C)Oc2ccccc2)cc1 with predicted y =  -0.008059392657344233  and true y =  -0.044122009999999934
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(C)COc2ccccc2)cc1 with predicted y =  -0.008053942053606988  and true y =  -0.06608047999999989
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COc1ccc(C(c2ccccc2)C(C)Oc2ccccc2)cc1 with predicted y =  -0.007964723452218436  and true y =  -0.08090993000000002
# Current best molecule is  COc1ccc(C(C)C(OC)c2ccccc2)cc1  with true y =  -0.002599550000000006
# Next molecule to evaluate is  COC(Oc1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(-c2ccccc2)cc1 with predicted y =  -0.008192750302811191  and true y =  -0.17521978999999988
# List of HBEs with 1.40 V < Eox < 1.70 V:
# COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)OC)cc1
# COCOC(c1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(-c2ccccc2)cc1
# COc1ccc(C(c2ccccc2)(c2ccccc2)C(OC)c2ccccc2)cc1
# COCOC(Br)C(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1
# COCOC(c1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1
# COCOC(Br)Cc1ccc(OC)cc1
# COCCc1ccc(OC)cc1
# COCOC(OC)C(c1ccccc1)c1ccc(OC)cc1
# COCOC(C)Cc1ccc(OC)cc1
# COCOCCc1ccc(OC)cc1
# COc1ccc(CC(OC)OC)cc1
# COc1ccc(C(C)C(OC)Oc2ccccc2)cc1
# COCOCC(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(C(COc2ccccc2)(c2ccccc2)c2ccccc2)cc1
# COCOC(Cc1ccc(OC)cc1)OC
# COc1ccc(C(C)(C)C(OC)OC)cc1
# COC(c1ccccc1)C(c1ccccc1)(c1ccccc1)c1ccc(-c2ccccc2)cc1
# COCC(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(C(C)(C)C(OC)Oc2ccccc2)cc1
# COc1ccc(C(C)(c2ccccc2)C(C)OC)cc1
# COc1ccc(C(c2ccccc2)C(Br)OC)cc1
# COc1ccc(C(c2ccccc2)(c2ccccc2)C(Oc2ccccc2)c2ccccc2)cc1
# COc1ccc(C(C)(c2ccccc2)C(OC)c2ccccc2)cc1
# COCOC(C)C(C)(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(C(c2ccccc2)(c2ccccc2)C(Br)Oc2ccccc2)cc1
# COCOC(OC)C(C)(C)c1ccc(OC)cc1
# COCOC(OC)C(C)c1ccc(OC)cc1
# COc1ccc(C(C)(c2ccccc2)C(OC)OC)cc1
# COCOC(OC)C(C)(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(C(c2ccccc2)C(OC)c2ccccc2)cc1
# COc1ccc(C(C)C(OC)OC)cc1
# COc1ccc(C(C)C(C)OC)cc1
# COCOCC(C)c1ccc(OC)cc1
# COCOCC(c1ccccc1)c1ccc(OC)cc1
# COCOC(C)C(C)c1ccc(OC)cc1
# COc1ccc(C(C)(c2ccccc2)C(OC)Oc2ccccc2)cc1
# COc1ccc(C(C)C(OC)c2ccccc2)cc1
# COc1ccc(C(c2ccccc2)C(C)OC)cc1
# COc1ccc(C(c2ccccc2)C(OC)Oc2ccccc2)cc1
# COc1ccc(C(c2ccccc2)C(OC)OC)cc1
# COc1ccc(C(C)(C)C(C)OC)cc1
# COc1ccc(C(C)(C)C(OC)c2ccccc2)cc1
# COCOC(c1ccccc1)C(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(CC(C)OC)cc1
# COCC(c1ccccc1)(c1ccccc1)c1ccc(OC)cc1
# COCC(C)c1ccc(OC)cc1
# COCOC(C)C(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(C(c2ccccc2)C(Oc2ccccc2)c2ccccc2)cc1
# COc1ccc(C(c2ccccc2)(c2ccccc2)C(C)OC)cc1
# COCOCC(C)(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(CC(OC)Oc2ccccc2)cc1
# COCOCC(C)(C)c1ccc(OC)cc1
# COCOC(C)C(C)(C)c1ccc(OC)cc1
# COCC(C)(C)c1ccc(OC)cc1
# COCOC(c1ccccc1)C(C)c1ccc(OC)cc1
# COCC(C)(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(CC(OC)c2ccccc2)cc1
# COCOC(c1ccccc1)C(C)(c1ccccc1)c1ccc(OC)cc1
# COc1ccc(C(C)C(C)Oc2ccccc2)cc1
# COc1ccc(C(C)(C)C(C)Oc2ccccc2)cc1
# COc1ccc(C(C)COc2ccccc2)cc1
# COc1ccc(C(c2ccccc2)C(C)Oc2ccccc2)cc1
